# %% [markdown]
# <a href="https://colab.research.google.com/github/Iswarya-1705/Image_Recognition_System_Model/blob/main/Image_Recognition_System_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMAGE RECOGNITION SYSTEM MODEL

# %%
# !pip install flask flask-ngrok tensorflow opencv-python pillow

# %%
from pyngrok import ngrok, conf

# Set your ngrok authtoken
conf.get_default().auth_token = "2wanhAwexLcZGDHIsU4ma6I0C05_6VDUfALWk7SAd3boqzB5"

# %%
# Connect ngrok to your Flask app
public_url = ngrok.connect(5000)
print(" * Ngrok URL:", public_url)
# Out:
#  * Ngrok URL: NgrokTunnel: "https://7758-35-184-197-131.ngrok-free.app" -> "http://localhost:5000"

# %%
from flask import Flask
from flask_ngrok import run_with_ngrok

app = Flask(__name__)
run_with_ngrok(app)  # This will automatically open the Ngrok URL

@app.route("/")
def home():
    return "Hello from Flask in Google Colab!"

if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit

# %%
from flask import Flask, render_template_string, request
from flask_ngrok import run_with_ngrok
import tensorflow as tf
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input, decode_predictions
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing import image
import numpy as np
from PIL import Image
import io
from pyngrok import ngrok, conf

# Set your ngrok authtoken
conf.get_default().auth_token = "2wanhAwexLcZGDHIsU4ma6I0C05_6VDUfALWk7SAd3boqzB5"

# Initialize Flask app
app = Flask(__name__)

# Start ngrok tunnel
public_url = ngrok.connect(5000)
print(" * Ngrok URL:", public_url)

# Function to load the MobileNetV2 model
model = MobileNetV2(weights="imagenet")

@app.route("/", methods=["GET", "POST"])
def index():
    if request.method == "POST":
        file = request.files["file"]
        img = Image.open(file.stream)

        # Preprocess the image for MobileNetV2
        img = img.resize((224, 224))
        img_array = np.array(img)
        img_array = np.expand_dims(img_array, axis=0)
        img_array = preprocess_input(img_array)

        # Make prediction
        predictions = model.predict(img_array)
        decoded_predictions = decode_predictions(predictions, top=3)[0]

        result = ""
        for i, (imagenet_id, label, score) in enumerate(decoded_predictions):
            result += f"{i + 1}. {label}: {score:.2f}\n"

        return render_template_string("<h1>Prediction Results</h1><pre>{{ result }}</pre>", result=result)

    return '''
        <!doctype html>
        <html lang="en">
        <head>
            <meta charset="UTF-8">
            <meta name="viewport" content="width=device-width, initial-scale=1.0">
            <title>Image Classifier</title>
        </head>
        <body>
            <h1>Upload an image</h1>
            <form method="POST" enctype="multipart/form-data">
                <input type="file" name="file">
                <button type="submit">Submit</button>
            </form>
        </body>
        </html>
    '''

if __name__ == "__main__":
    run_with_ngrok(app)  # Start ngrok when running the app
    app.run()
# Out:
#  * Ngrok URL: NgrokTunnel: "https://02bf-35-184-197-131.ngrok-free.app" -> "http://localhost:5000"
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
#  * Running on http://02bf-35-184-197-131.ngrok-free.app
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [03/May/2025 17:23:28] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [03/May/2025 17:23:29] "GET /favicon.ico HTTP/1.1" 404 -
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# INFO:werkzeug:127.0.0.1 - - [03/May/2025 17:24:11] "POST / HTTP/1.1" 200 -
